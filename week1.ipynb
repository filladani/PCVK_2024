# %% [markdown]
# <a href="https://colab.research.google.com/github/filladani/PCVK_2024/blob/main/week1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow # for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
# membuat list untuk menyimpan url dari beberapa image
urls = ["https://asset-2.tstatic.net/tribunnews/foto/bank/images/keliling-desa-wisata-kembang-kuning-sambil-menikmati-keindahan-lanskap-gunung-rinjani.jpg",
        "https://www.trekkingrinjani.com/mendakigunungrinjani/images/danau-segara-anak1.jpg",
        "https://picture.triptrus.com/image/2014/06/taman-nasional-gunung-rinjani-6.jpeg"

]
# baca tampilan image
# loop pada tiap url image, beberapa image dapat disimpan pada list
for url in urls :
  image = io.imread(url)                              # read image
  image = cv.resize(image, (0,0), fx=0.5, fy=0.5)     # resize image to half size
  image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)       # convert color to RGB
  final_frame = cv.hconcat((image, image_2))          # concatenate image
  cv2_imshow (final_frame)                            # show image
  print('\n')
# Out:
# <PIL.Image.Image image mode=RGB size=700x196>
# <PIL.Image.Image image mode=RGB size=900x299>
# <PIL.Image.Image image mode=RGB size=884x291>

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
print ("resolusi image : tinggi x lebar =", tinggi," x ",lebar)
cv2_imshow(image_2)
# Out:
# resolusi image : tinggi x lebar = 291  x  442
# <PIL.Image.Image image mode=RGB size=442x291>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=884x291>

# %% [markdown]
# 1. karena didalam google collab terdapat library python yang mudah cara penggunaannya yaitu dengan cara memanggilnya, selain itu google collab juga mudah dihubungkan dengan github.
# 2.
# - numpy : Untuk komputasi numerik, ia menyediakan struktur array yang efisien.
# - pandas : Modul untuk analisis dan manipulasi data.
# - cv2 : Untuk pengolahan gambar dan komputer visi.
# - skimage : Modul untuk pemrosesan gambar yang lebih tingkat tinggi.
# - PIL : Modul untuk manipulasi gambar yang mencakup operasi dasar seperti pembukaan, penyimpanan, dan manipulasi sederhana.
# - matplotlib : Menghasilkan gambar dan menyediakan perangkat antarmuka.
# 3.
# - 'cv.resize' merupakan modul openCV untuk meresize gambar.
# - 'image' merupakan gambar yang akan di resize.
# - '0,0' merupakan titik pusat rotasi.
# - 'fx=0,5' merupakan faktor skala horizontal, gambar akan diubah menjadi setengah lebar aslinya.
# - 'fy=0.5' merupakan faktor skala vertikal.gambar akan diubah menjadi setengah tinggi aslinya.
# 4. kode [255,255,255] merupakan kode warna putih, namun fungsi dari kode tersebut yaitu digunakan untuk memberikan warna pada gambar tersebut yang output warnanya sesuai dengan kodenya.
# 5. Resolusi gambar merupakan jumlah pixel yang terdapat pada gambar. jika resolusi rendah maka jumlah pixelnya sedikit dan jika resolusi tinggi maka jumlah pixelnya banyak

# %%
#2. Buat garis vertikal dan garis menyilang diagonal pada image keluaran
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_4 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_5 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for x in range (tinggi):
  image_3[x, int((lebar)/2)] = [255,255,255]

for y in range (lebar):
  image_5[int((tinggi/lebar*y)),y] = [255,255,255]
  image_5[int((tinggi/lebar*y)),-y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
final_frame2 = cv.hconcat((image_4, image_5))
cv2_imshow(final_frame)
cv2_imshow(final_frame2)
# Out:
# <PIL.Image.Image image mode=RGB size=884x291>
# <PIL.Image.Image image mode=RGB size=884x291>

# %%
#3. Buat garis horizontal berwarna putih dibagian
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (lebar):
  if(y>100 and y<200):
    image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=884x291>

# %%
#4. Buat kotak menggunakan kumpulan pixel warna putih
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

#membuat garis horizontal ditengah image
for y in range (100,200):
  for x in range (100,200):
    image_3[x,y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=884x291>
