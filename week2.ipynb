# %% [markdown]
# <a href="https://colab.research.google.com/github/filladani/PCVK_2024/blob/main/week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accesing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)  #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

#tampilkan plot dengan ukuran canvas yang lebih besar
fig = plt.figure(figsize=(10,10))     #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_COMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# # Jawaban Pertanyaan
# 1. Dengan matplotlib dapat memvisualisasikan data seperti garis, scatter plot, dan diagram batang. Dan juga dapat menyesuaikan gambar dari warna dan aspek lainnya.
#
# 2. Ketika menggunakan int16, gambar menjadi kurang tajam jika dibanding dengan int32. Tetapi int16 menggunakan lebih sedikit penyimpanan memori
#
# 3. Fungsinya untuk menampilkan gambar pada google colab menggunakan openCV tanpa harus menyimpan gambar dulu
#
# 4. Berfungsi untuk bekerja dengan gambar yang masih butuh pemrosesan lanjutan pada python

# %% [markdown]
# # tugas no 1
# Tidak berubah, yang berubah hanya ukuran gambar yang ditampilkan pada plot saja.

# %%
# Tugas no.2
# Red-Blue
img = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg')
rb = img.copy()
rb[:,:,1] = 0

plt.imshow(cv.cvtColor(rb, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Green-Blue
gb = img.copy()
gb[:,:,2] = 0

plt.imshow(cv.cvtColor(gb, cv.COLOR_BGR2RGB))
plt.axis('off')
plt.show()

# %%
# Tugas no.3
crop = img[20:115, 25:120]

plt.imshow(cv.cvtColor(crop, cv.COLOR_BGR2RGB))
plt.show()

# %%
# Tugas No.4
crop2 = cv.imread('/content/drive/MyDrive/PCVK/images/cat.jpg' , cv.IMREAD_GRAYSCALE)
plt.imshow(crop2[5:30],cmap="Reds")

# %%
# Tugas NO.5
img10 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img10,pt1=(50,10),pt2=(110,150),color=(0,255,0),thickness=10)
cv.rectangle(img10,pt1=(350,0),pt2=(500,150),color=(0,0,200),thickness=5)
cv.rectangle(img10,pt1=(200,200),pt2=(300,300),color=(120,0,0),thickness=6)
cv.rectangle(img10,pt1=(400,100),pt2=(350,250),color=(0,255,170),thickness=8)
cv.rectangle(img10,pt1=(100,400),pt2=(250,350),color=(210,255,0),thickness=6)
plt.imshow(img10)

# %%
#Tugas No.6
img11 = cv.flip(img10,0)
plt.imshow(img11)

# %%
# Tugas No.7
foto = cv.imread('/content/drive/MyDrive/PCVK/images/saya.JPG')
foto = cv.cvtColor(foto,cv.COLOR_BGR2RGB)
cv.rectangle(foto,pt1=(2300,2700),pt2=(1100,1500),color=(255, 165, 0),thickness=25)
cv.circle(foto,center=(1700,2150),radius=400,color=(255, 0, 0),thickness=15)
plt.imshow(foto)

# %%
# Tugas No.8
blue = cv.cvtColor(img,cv.COLOR_BGR2RGB)
blue[200:300,100:200,1] = 0
blue[200:300,100:200,0] = 0

plt.imshow(blue)

# %%
# Tugas No.9
font=cv.FONT_HERSHEY_SIMPLEX
cv.putText(blue,text='cat',org=(200,800),fontFace=font,fontScale=5,color=(0,255,255),thickness=5,lineType=cv.LINE_AA)
plt.imshow(blue)

# %% [markdown]
# # Tugas Kelompok

# %%
ktp = cv.imread('/content/drive/MyDrive/PCVK/images/ktp.png')
ktp = cv.cvtColor(ktp,cv.COLOR_BGR2RGB)
plt.imshow(ktp)

# %%
cv.rectangle(ktp, pt1=(250,290), pt2=(650,310), color=(255,0,0), thickness=5)
cv.rectangle(ktp, pt1=(250,380), pt2=(410,400), color=(0,0,255), thickness=5)
plt.imshow(ktp)
